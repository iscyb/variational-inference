# %% [markdown]
# # CAVI - Coordinate Ascent VI
#
# CAVI is the main analytical algorithm for maximizing the ELBO assuming mean field variational family
#
# *"CAVI is good but doesnt scale with large dataset" - seem quite pointless then? Since VI primary advatnage over MCMC is ability to handle large dataset.*
#
# ## Example: (Bayesian) Gaussian Mixture Model (GMM)
#
# $\mu_k \sim N(0,\sigma^2), k = 1, ..., K$ - prior means of clusters
#
# $ c_i \sim Cat(1/K, ..., 1/K),$ K categories, $i = 1,...., n$
#
# $x_i |_{c_i, \mu} \sim N(c_i^T \mu, 1) $ $\mu$ is the vector of all $\mu_k ?$
#
#
# - $\sigma$ is hyperparameter
# - $c_i$ is one hot
# - In regular GMM we dont have $\mu_k$
# - denote all observations $(x_i)_i = x$
#
# We want to find posterior cluster assignment $p(c_i|x_i)$ [prob of xi belonging to c_i] and posterior mixture components $p(\mu_k|$) [prob $\mu_k$ given all our data]
# Note that cluster centers are not correlated, which give us the second equality.
#
# ![image.png](attachment:image.png)
#
# Note that cluster means are uncorrelated which explain the 2nd equality of 2nd eq
#
# Mean field in 3rd eq
#
# ![image.png](attachment:image-2.png)

# %%
# Note c_i coded as one hot
